# %% [markdown]
# # trodes_to_nwb
#
# This tutorial will give a demonstration of the basic conversion process using `trodes_to_nwb`.
#
# ### Download demo data.
# First we need to download sample data to use in this conversion, and define the path to this data.  The files at this link contain ~10 seconds of data we can use for testing:
#
# [DATA DOWNLOAD](https://ucsf.box.com/s/9oc1yjkjp30a4vhx0xv1eayu197530qk)
#
# We then need to define the path to the downloaded data:

# %%
data_path = "path/to/data/trodes_to_nwb_demo/"

# %% [markdown]
# ### Basic Conversion.
# We'll start with a standard conversion using the `create_nwbs` function.
#
# #### Arguments
# + `data_path`:\
# The create function recursively searches the path argument for files matching the naming convention:\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`{date}_{animal}_{epoch}_{tag}.extension`\
# Groupings of sessions and epochs are done specifically on these namings, so ensure accuracy. Once the files have been found, a nwb file will be created for each Session (animal+date) with files found in the directory
# \
# \
# Your yml file containing metadata for this experiment should be in this directory with the name `{date}_{animal}_metadata.yml`. We *__highly__* recommend using the yaml creator [HERE](https://lorenfranklab.github.io/rec_to_nwb_yaml_creator/) to generate these files in order to ensure proper formatting for conversion.
#
# + `probe_metadata_paths`:
# a list of paths to probe metadata .yaml files. If None, the conversion will look through a list of probe yaml files included in the package for ones matching those defined in your yaml metadatar.
#
# + `output_dir`:
# Where the nwb file will be saved. For Frank Lab members, this should be `/stelmo/nwb/raw/`. File is named by the convention {animal}{date}.nwb
#
# + `query_expression`: A query expression to select which files to convert. For example, if you have several animals in your folder, you could write `"animal == 'sample'"` to select only the sample animal. Defaults to `None` which converts all files in the directory (potentially overwriting ones you've done before!).
#
# + `behavior_only`: Rec files recorded through trodes software without e-phys data have a
#    different expected internal structure. Use this flag to ensure correct data parsing
#    is used. Default of `False` expects electrophysiology data to be present

# %%
from trodes_to_nwb.convert import create_nwbs

# restrict conversion to a single session, ignores the reconfig metadata in the download
exclude_reconfig_yaml = str(data_path + "20230622_sample_metadataProbeReconfig.yml")
query_expression = f"animal == 'sample' and date == 20230622 and full_path != '{exclude_reconfig_yaml}'"

create_nwbs(
    path=data_path,
    probe_metadata_paths=None,
    output_dir="/stelmo/temp/",  # saving to a temporary directory to not clutter up the database.  Please delete when done.
    query_expression=query_expression,
)
# Out:
# 07-Nov-23 15:49:46 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:49:46 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:49:46 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:49:46 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:49:46 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:49:46 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:49:46 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:49:46 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:49:46 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:49:46 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:49:46 CREATING REC DATA ITERATORS
# 07-Nov-23 15:49:46 CREATING REC DATA ITERATORS
# 07-Nov-23 15:49:46 CREATING REC DATA ITERATORS
# 07-Nov-23 15:49:46 CREATING REC DATA ITERATORS
# 07-Nov-23 15:49:46 CREATING REC DATA ITERATORS
# 07-Nov-23 15:49:46 Parsing headers
# 07-Nov-23 15:49:46 Parsing headers
# 07-Nov-23 15:49:46 Parsing headers
# 07-Nov-23 15:49:46 Parsing headers
# 07-Nov-23 15:49:46 Parsing headers
# 07-Nov-23 15:49:46 Parsing header COMPLETE
# 07-Nov-23 15:49:46 Parsing header COMPLETE
# 07-Nov-23 15:49:46 Parsing header COMPLETE
# 07-Nov-23 15:49:49 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:49:49 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:49:49 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:49:49 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:49:49 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:49:49 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# 07-Nov-23 15:49:49 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# 07-Nov-23 15:49:49 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# 07-Nov-23 15:49:49 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# 07-Nov-23 15:49:49 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# /home/sambray/Documents/trodes_to_nwb/src/trodes_to_nwb/convert_position.py:126: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# 07-Nov-23 15:49:49 repeat timestamps ind: []
# 07-Nov-23 15:49:49 repeat timestamps ind: []
# 07-Nov-23 15:49:49 repeat timestamps ind: []
# 07-Nov-23 15:49:49 repeat timestamps ind: []
# 07-Nov-23 15:49:49 repeat timestamps ind: []
# 07-Nov-23 15:49:49 big frame jumps: [8]
# 07-Nov-23 15:49:49 big frame jumps: [8]
# 07-Nov-23 15:49:49 big frame jumps: [8]
# 07-Nov-23 15:49:49 big frame jumps: [8]
# 07-Nov-23 15:49:49 big frame jumps: [8]
# 07-Nov-23 15:49:49 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:49:49 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:49:49 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:49:49 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:49:49 	non_repeat_timestamp_labels = [1]
# /home/sambray/Documents/trodes_to_nwb/src/trodes_to_nwb/convert_position.py:126: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# 07-Nov-23 15:49:49 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:49:49 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:49:49 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:49:49 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:49:49 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:49:49 2
# 07-Nov-23 15:49:49 2
# 07-Nov-23 15:49:49 2
# 07-Nov-23 15:49:49 2
# 07-Nov-23 15:49:49 2
# 07-Nov-23 15:49:49 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:49:49 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:49:49 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:49:49 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:49:49 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:49:49 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# 07-Nov-23 15:49:49 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# 07-Nov-23 15:49:49 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# 07-Nov-23 15:49:49 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# 07-Nov-23 15:49:49 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# /home/sambray/Documents/trodes_to_nwb/src/trodes_to_nwb/convert_position.py:126: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# 07-Nov-23 15:49:49 repeat timestamps ind: []
# 07-Nov-23 15:49:49 repeat timestamps ind: []
# 07-Nov-23 15:49:49 repeat timestamps ind: []
# 07-Nov-23 15:49:49 repeat timestamps ind: []
# 07-Nov-23 15:49:49 repeat timestamps ind: []
# 07-Nov-23 15:49:49 big frame jumps: []
# 07-Nov-23 15:49:49 big frame jumps: []
# 07-Nov-23 15:49:49 big frame jumps: []
# 07-Nov-23 15:49:49 big frame jumps: []
# 07-Nov-23 15:49:49 big frame jumps: []
# 07-Nov-23 15:49:49 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:49:49 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:49:49 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:49:49 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:49:49 	non_repeat_timestamp_labels = [1]
# /home/sambray/Documents/trodes_to_nwb/src/trodes_to_nwb/convert_position.py:126: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# 07-Nov-23 15:49:49 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:49:49 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:49:49 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:49:49 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:49:49 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:49:49 WRITING: /stelmo/temp/sample20230622.nwb
# 07-Nov-23 15:49:49 WRITING: /stelmo/temp/sample20230622.nwb
# 07-Nov-23 15:49:49 WRITING: /stelmo/temp/sample20230622.nwb
# 07-Nov-23 15:49:49 WRITING: /stelmo/temp/sample20230622.nwb
# 07-Nov-23 15:49:49 WRITING: /stelmo/temp/sample20230622.nwb
# compute multiplex cache /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec
# compute multiplex cache /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec
# 07-Nov-23 15:49:55 RUNNING NWB INSPECTOR
# 07-Nov-23 15:49:55 RUNNING NWB INSPECTOR
# 07-Nov-23 15:49:55 RUNNING NWB INSPECTOR
# 07-Nov-23 15:49:55 RUNNING NWB INSPECTOR
# 07-Nov-23 15:49:55 RUNNING NWB INSPECTOR
# 07-Nov-23 15:49:56 NWB Inspector output:
# 07-Nov-23 15:49:56 NWB Inspector output:
# 07-Nov-23 15:49:56 NWB Inspector output:
# 07-Nov-23 15:49:56 NWB Inspector output:
# 07-Nov-23 15:49:56 NWB Inspector output:
# 07-Nov-23 15:49:56 [InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/10',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/11',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/12',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/13',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/14',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/15',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/16',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/17',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/18',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/19',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/20',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/21',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/22',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/23',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/24',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/25',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/26',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/27',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/28',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/29',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/3',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/30',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/31',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/4',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/5',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/6',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/7',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/8',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/9',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 9',
#     location='/general/devices/probe 9',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 8',
#     location='/general/devices/probe 8',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 7',
#     location='/general/devices/probe 7',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 6',
#     location='/general/devices/probe 6',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 5',
#     location='/general/devices/probe 5',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 4',
#     location='/general/devices/probe 4',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 31',
#     location='/general/devices/probe 31',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 30',
#     location='/general/devices/probe 30',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 3',
#     location='/general/devices/probe 3',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 29',
#     location='/general/devices/probe 29',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 28',
#     location='/general/devices/probe 28',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 27',
#     location='/general/devices/probe 27',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 26',
#     location='/general/devices/probe 26',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 25',
#     location='/general/devices/probe 25',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 24',
#     location='/general/devices/probe 24',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 23',
#     location='/general/devices/probe 23',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 22',
#     location='/general/devices/probe 22',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 21',
#     location='/general/devices/probe 21',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 20',
#     location='/general/devices/probe 20',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 2',
#     location='/general/devices/probe 2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 19',
#     location='/general/devices/probe 19',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 18',
#     location='/general/devices/probe 18',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 17',
#     location='/general/devices/probe 17',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 16',
#     location='/general/devices/probe 16',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 15',
#     location='/general/devices/probe 15',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 14',
#     location='/general/devices/probe 14',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 13',
#     location='/general/devices/probe 13',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 12',
#     location='/general/devices/probe 12',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 11',
#     location='/general/devices/probe 11',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 10',
#     location='/general/devices/probe 10',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 1',
#     location='/general/devices/probe 1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 0',
#     location='/general/devices/probe 0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='HeaderDevice',
#     object_name='header_device',
#     location='/general/devices/header_device',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DataAcqDevice',
#     object_name='dataacq_device0',
#     location='/general/devices/dataacq_device0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='CameraDevice',
#     object_name='camera_device 1',
#     location='/general/devices/camera_device 1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='CameraDevice',
#     object_name='camera_device 0',
#     location='/general/devices/camera_device 0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DynamicTable',
#     object_name='task_1',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DynamicTable',
#     object_name='task_0',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_2',
#     location='/processing/position_frame_index/series_2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_1',
#     location='/processing/position_frame_index/series_1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_2',
#     location='/processing/non_repeat_timestamp_labels/series_2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_1',
#     location='/processing/non_repeat_timestamp_labels/series_1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='ElectricalSeries',
#     object_name='e-series',
#     location='/acquisition/e-series',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="The external file '20230622_sample_02_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.",
#     importance=<Importance.CRITICAL: 2>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_image_series_external_file_valid',
#     object_type='ImageSeries',
#     object_name='20230622_sample_02_a1.1.h264',
#     location='/processing/video_files/video/20230622_sample_02_a1.1.h264',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="The external file '20230622_sample_01_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.",
#     importance=<Importance.CRITICAL: 2>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_image_series_external_file_valid',
#     object_type='ImageSeries',
#     object_name='20230622_sample_01_a1.1.h264',
#     location='/processing/video_files/video/20230622_sample_01_a1.1.h264',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='data is not compressed. Consider enabling compression when writing a dataset.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_small_dataset_compression',
#     object_type='ElectricalSeries',
#     object_name='e-series',
#     location='/acquisition/e-series',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Metadata /general/keywords is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_keywords',
#     object_type='NWBFile',
#     object_name='root',
#     location='/',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named video_files. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='video_files',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named tasks. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='tasks',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named sample_count. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='sample_count',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ...
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 2',
#     location='/general/devices/probe 2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 19',
#     location='/general/devices/probe 19',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 18',
#     location='/general/devices/probe 18',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 17',
#     location='/general/devices/probe 17',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 16',
#     location='/general/devices/probe 16',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 15',
#     location='/general/devices/probe 15',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 14',
#     location='/general/devices/probe 14',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 13',
#     location='/general/devices/probe 13',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 12',
#     location='/general/devices/probe 12',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 11',
#     location='/general/devices/probe 11',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 10',
#     location='/general/devices/probe 10',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 1',
#     location='/general/devices/probe 1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 0',
#     location='/general/devices/probe 0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='HeaderDevice',
#     object_name='header_device',
#     location='/general/devices/header_device',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DataAcqDevice',
#     object_name='dataacq_device0',
#     location='/general/devices/dataacq_device0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='CameraDevice',
#     object_name='camera_device 1',
#     location='/general/devices/camera_device 1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='CameraDevice',
#     object_name='camera_device 0',
#     location='/general/devices/camera_device 0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DynamicTable',
#     object_name='task_1',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DynamicTable',
#     object_name='task_0',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_2',
#     location='/processing/position_frame_index/series_2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_1',
#     location='/processing/position_frame_index/series_1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_2',
#     location='/processing/non_repeat_timestamp_labels/series_2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_1',
#     location='/processing/non_repeat_timestamp_labels/series_1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='ElectricalSeries',
#     object_name='e-series',
#     location='/acquisition/e-series',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="The external file '20230622_sample_02_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.",
#     importance=<Importance.CRITICAL: 2>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_image_series_external_file_valid',
#     object_type='ImageSeries',
#     object_name='20230622_sample_02_a1.1.h264',
#     location='/processing/video_files/video/20230622_sample_02_a1.1.h264',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="The external file '20230622_sample_01_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.",
#     importance=<Importance.CRITICAL: 2>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_image_series_external_file_valid',
#     object_type='ImageSeries',
#     object_name='20230622_sample_01_a1.1.h264',
#     location='/processing/video_files/video/20230622_sample_01_a1.1.h264',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='data is not compressed. Consider enabling compression when writing a dataset.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_small_dataset_compression',
#     object_type='ElectricalSeries',
#     object_name='e-series',
#     location='/acquisition/e-series',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Metadata /general/keywords is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_keywords',
#     object_type='NWBFile',
#     object_name='root',
#     location='/',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named video_files. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='video_files',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named tasks. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='tasks',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named sample_count. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='sample_count',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named position_frame_index. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='position_frame_index',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named non_repeat_timestamp_labels. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='non_repeat_timestamp_labels',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named associated_files. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='associated_files',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named analog. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='analog',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='This table has only a single row; it may be better represented by another data type.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_single_row',
#     object_type='DynamicTable',
#     object_name='task_1',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='This table has only a single row; it may be better represented by another data type.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_single_row',
#     object_type='DynamicTable',
#     object_name='task_0',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# )]
# 07-Nov-23 15:49:56 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:49:56 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:49:56 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:49:56 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:49:56 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:49:56 DONE
# 07-Nov-23 15:49:56 DONE
# 07-Nov-23 15:49:56 DONE
# 07-Nov-23 15:49:56 DONE
# 07-Nov-23 15:49:56 DONE
# NWB Inspector found the following 2 critical errors:
#
#
# **************************************************
# NWBInspector Report Summary
#
# Timestamp: 2023-11-07 15:49:56.563756-08:00
# Platform: Linux-5.4.0-164-generic-x86_64-with-glibc2.31
# NWBInspector version: 0.4.31
#
# Found 2 issues over 1 files:
#        2 - CRITICAL
# **************************************************
#
#
# 0  /stelmo/temp/sample20230622.nwb
# ==================================
#
# 0.0  Importance.CRITICAL: check_image_series_external_file_valid - 'ImageSeries' object at location '/processing/video_files/video/20230622_sample_02_a1.1.h264'
#        Message: The external file '20230622_sample_02_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.
#
# 0.1  Importance.CRITICAL: check_image_series_external_file_valid - 'ImageSeries' object at location '/processing/video_files/video/20230622_sample_01_a1.1.h264'
#        Message: The external file '20230622_sample_01_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.
#
# NWB Inspector found 0 best practice violations
# NWB Inspector found 54 best practice suggestions
# Please see /stelmo/temp/sample20230622_nwbinspector_report.txt for the full NWB Inspector report

# %% [markdown]
# File generation will create a log file for each session converted in the directory where the code is executed.  This can be used to track progress and debug

# %% [markdown]
# ### Reconfig Files
#
# Sometimes, the grouping of nTrodes objects in a .rec file does not reflect the grouping of electrodes on the physical recording device.  This is often the case when collecting probe data, where the many electrodes on a probe may be made into smaller groups in the Trodes software for convenience during recording.
#
# In these cases, the user should create a .reconfig file.  This file is the same as the xml header in the rec file, but allows the user to adjust the Ntrode groupings, reference channels, etc.  Note that unlike rec_to_nwb, trodes_to_nwb enforces agreement between the reconfig file and metadata yaml to avoid silent errors.
#
# To use a reconfig header, just provide the filepath in the parameter `header_reconfig_path`. Use the default value None to use no reconfiguration.
#
# Key info taken from reconfig file:
# * ntrodes groupings
# * HWchan
# * reference electrodes

# %%
# ex) probe reconfiguration
from trodes_to_nwb.tests.utils import (
    data_path as package_data_path,
)  # path to package test data

reconfig_path = (
    package_data_path / "reconfig_probeDevice.trodesconf"
)  # path to reconfiguration file

# restrict conversion to a single session, ignores the non-reconfig metadata in the download
exclude_non_reconfig_yaml = str(data_path + "20230622_sample_metadata.yml")
query_expression = f"animal == 'sample' and date == 20230622 and full_path != '{exclude_non_reconfig_yaml}'"

create_nwbs(
    path=data_path,
    probe_metadata_paths=None,
    output_dir="/stelmo/temp/",  # saving to a temporary directory to not clutter up the database.  Please delete when done.
    header_reconfig_path=reconfig_path,
    query_expression=query_expression,
)
# Out:
# 07-Nov-23 15:54:16 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:54:16 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:54:16 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:54:16 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:54:16 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:54:16 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:54:16 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:54:16 Creating NWB file for session: (20230622, 'sample')
# 07-Nov-23 15:54:16 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:16 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:16 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:16 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:16 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:16 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:16 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:16 	rec_filepaths: ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec', '/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:16 CREATING REC DATA ITERATORS
# 07-Nov-23 15:54:16 CREATING REC DATA ITERATORS
# 07-Nov-23 15:54:16 CREATING REC DATA ITERATORS
# 07-Nov-23 15:54:16 CREATING REC DATA ITERATORS
# 07-Nov-23 15:54:16 CREATING REC DATA ITERATORS
# 07-Nov-23 15:54:16 CREATING REC DATA ITERATORS
# 07-Nov-23 15:54:16 CREATING REC DATA ITERATORS
# 07-Nov-23 15:54:16 CREATING REC DATA ITERATORS
# 07-Nov-23 15:54:16 Parsing headers
# 07-Nov-23 15:54:16 Parsing headers
# 07-Nov-23 15:54:16 Parsing headers
# 07-Nov-23 15:54:16 Parsing headers
# 07-Nov-23 15:54:16 Parsing headers
# 07-Nov-23 15:54:16 Parsing headers
# 07-Nov-23 15:54:16 Parsing headers
# 07-Nov-23 15:54:16 Parsing headers
# 07-Nov-23 15:54:16 Parsing header COMPLETE
# 07-Nov-23 15:54:16 Parsing header COMPLETE
# 07-Nov-23 15:54:16 Parsing header COMPLETE
# 07-Nov-23 15:54:16 Parsing header COMPLETE
# 07-Nov-23 15:54:16 Parsing header COMPLETE
# 07-Nov-23 15:54:16 Parsing header COMPLETE
# 07-Nov-23 15:54:16 Parsing header COMPLETE
# 07-Nov-23 15:54:16 Parsing header COMPLETE
# 07-Nov-23 15:54:16 # iterators: 2
# 07-Nov-23 15:54:16 # iterators: 2
# 07-Nov-23 15:54:16 # iterators: 2
# 07-Nov-23 15:54:16 # iterators: 2
# 07-Nov-23 15:54:16 # iterators: 2
# 07-Nov-23 15:54:16 # iterators: 2
# 07-Nov-23 15:54:16 # iterators: 2
# 07-Nov-23 15:54:16 # iterators: 2
# 07-Nov-23 15:54:17 Reading timestamps COMPLETE
# 07-Nov-23 15:54:17 Reading timestamps COMPLETE
# 07-Nov-23 15:54:17 Reading timestamps COMPLETE
# 07-Nov-23 15:54:17 Reading timestamps COMPLETE
# 07-Nov-23 15:54:17 Reading timestamps COMPLETE
# 07-Nov-23 15:54:17 Reading timestamps COMPLETE
# 07-Nov-23 15:54:17 Reading timestamps COMPLETE
# 07-Nov-23 15:54:17 Reading timestamps COMPLETE
# 07-Nov-23 15:54:17 	metadata_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_metadataProbeReconfig.yml
# 07-Nov-23 15:54:17 	metadata_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_metadataProbeReconfig.yml
# 07-Nov-23 15:54:17 	metadata_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_metadataProbeReconfig.yml
# 07-Nov-23 15:54:17 	metadata_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_metadataProbeReconfig.yml
# 07-Nov-23 15:54:17 	metadata_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_metadataProbeReconfig.yml
# 07-Nov-23 15:54:17 	metadata_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_metadataProbeReconfig.yml
# 07-Nov-23 15:54:17 	metadata_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_metadataProbeReconfig.yml
# 07-Nov-23 15:54:17 	metadata_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_metadataProbeReconfig.yml
# 07-Nov-23 15:54:18 CREATING HARDWARE MAPS
# 07-Nov-23 15:54:18 CREATING HARDWARE MAPS
# 07-Nov-23 15:54:18 CREATING HARDWARE MAPS
# 07-Nov-23 15:54:18 CREATING HARDWARE MAPS
# 07-Nov-23 15:54:18 CREATING HARDWARE MAPS
# 07-Nov-23 15:54:18 CREATING HARDWARE MAPS
# 07-Nov-23 15:54:18 CREATING HARDWARE MAPS
# 07-Nov-23 15:54:18 CREATING HARDWARE MAPS
# 07-Nov-23 15:54:18 CREATING METADATA ENTRIES
# 07-Nov-23 15:54:18 CREATING METADATA ENTRIES
# 07-Nov-23 15:54:18 CREATING METADATA ENTRIES
# 07-Nov-23 15:54:18 CREATING METADATA ENTRIES
# 07-Nov-23 15:54:18 CREATING METADATA ENTRIES
# 07-Nov-23 15:54:18 CREATING METADATA ENTRIES
# 07-Nov-23 15:54:18 CREATING METADATA ENTRIES
# 07-Nov-23 15:54:18 CREATING METADATA ENTRIES
# /home/sambray/mambaforge-pypy3/envs/spikegadgets_to_nwb/lib/python3.11/site-packages/pynwb/file.py:471: UserWarning: Date is missing timezone information. Updating to local timezone.
#   args_to_set['session_start_time'] = _add_missing_timezone(session_start_time)
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 ERROR: associated file path/ does not exist
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# 07-Nov-23 15:54:18 [Errno 2] No such file or directory: 'path/'
# /home/sambray/Documents/trodes_to_nwb/src/trodes_to_nwb/convert_position.py:126: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# cp: cannot create regular file '/20230622_sample_01_a1.1.h264': Permission denied
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.h264 has been copied to /20230622_sample_01_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.h264 has been copied to /20230622_sample_01_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.h264 has been copied to /20230622_sample_01_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.h264 has been copied to /20230622_sample_01_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.h264 has been copied to /20230622_sample_01_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.h264 has been copied to /20230622_sample_01_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.h264 has been copied to /20230622_sample_01_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.h264 has been copied to /20230622_sample_01_a1.1.h264
# /home/sambray/Documents/trodes_to_nwb/src/trodes_to_nwb/convert_position.py:126: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# cp: cannot create regular file '/20230622_sample_02_a1.1.h264': Permission denied
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.h264 has been copied to /20230622_sample_02_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.h264 has been copied to /20230622_sample_02_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.h264 has been copied to /20230622_sample_02_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.h264 has been copied to /20230622_sample_02_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.h264 has been copied to /20230622_sample_02_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.h264 has been copied to /20230622_sample_02_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.h264 has been copied to /20230622_sample_02_a1.1.h264
# 07-Nov-23 15:54:19 Video copy completed. /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.h264 has been copied to /20230622_sample_02_a1.1.h264
# 07-Nov-23 15:54:19 ADDING EPHYS DATA
# 07-Nov-23 15:54:19 ADDING EPHYS DATA
# 07-Nov-23 15:54:19 ADDING EPHYS DATA
# 07-Nov-23 15:54:19 ADDING EPHYS DATA
# 07-Nov-23 15:54:19 ADDING EPHYS DATA
# 07-Nov-23 15:54:19 ADDING EPHYS DATA
# 07-Nov-23 15:54:19 ADDING EPHYS DATA
# 07-Nov-23 15:54:19 ADDING EPHYS DATA
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 ADDING DIO DATA
# 07-Nov-23 15:54:19 ADDING DIO DATA
# 07-Nov-23 15:54:19 ADDING DIO DATA
# 07-Nov-23 15:54:19 ADDING DIO DATA
# 07-Nov-23 15:54:19 ADDING DIO DATA
# 07-Nov-23 15:54:19 ADDING DIO DATA
# 07-Nov-23 15:54:19 ADDING DIO DATA
# 07-Nov-23 15:54:19 ADDING DIO DATA
# Interpolate memmap:  /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec
# Interpolate memmap:  /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec
# 07-Nov-23 15:54:19 ADDING ANALOG DATA
# 07-Nov-23 15:54:19 ADDING ANALOG DATA
# 07-Nov-23 15:54:19 ADDING ANALOG DATA
# 07-Nov-23 15:54:19 ADDING ANALOG DATA
# 07-Nov-23 15:54:19 ADDING ANALOG DATA
# 07-Nov-23 15:54:19 ADDING ANALOG DATA
# 07-Nov-23 15:54:19 ADDING ANALOG DATA
# 07-Nov-23 15:54:19 ADDING ANALOG DATA
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing headers
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 Parsing header COMPLETE
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 # iterators: 2
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 Reading timestamps COMPLETE
# 07-Nov-23 15:54:19 ADDING SAMPLE COUNTS
# 07-Nov-23 15:54:19 ADDING SAMPLE COUNTS
# 07-Nov-23 15:54:19 ADDING SAMPLE COUNTS
# 07-Nov-23 15:54:19 ADDING SAMPLE COUNTS
# 07-Nov-23 15:54:19 ADDING SAMPLE COUNTS
# 07-Nov-23 15:54:19 ADDING SAMPLE COUNTS
# 07-Nov-23 15:54:19 ADDING SAMPLE COUNTS
# 07-Nov-23 15:54:19 ADDING SAMPLE COUNTS
# 07-Nov-23 15:54:19 ADDING EPOCHS
# 07-Nov-23 15:54:19 ADDING EPOCHS
# 07-Nov-23 15:54:19 ADDING EPOCHS
# 07-Nov-23 15:54:19 ADDING EPOCHS
# 07-Nov-23 15:54:19 ADDING EPOCHS
# 07-Nov-23 15:54:19 ADDING EPOCHS
# 07-Nov-23 15:54:19 ADDING EPOCHS
# 07-Nov-23 15:54:19 ADDING EPOCHS
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:19 ['/home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec']
# 07-Nov-23 15:54:19 ADDING POSITION
# 07-Nov-23 15:54:19 ADDING POSITION
# 07-Nov-23 15:54:19 ADDING POSITION
# 07-Nov-23 15:54:19 ADDING POSITION
# 07-Nov-23 15:54:19 ADDING POSITION
# 07-Nov-23 15:54:19 ADDING POSITION
# 07-Nov-23 15:54:19 ADDING POSITION
# 07-Nov-23 15:54:19 ADDING POSITION
# 07-Nov-23 15:54:19 PTP enabled: True
# 07-Nov-23 15:54:19 PTP enabled: True
# 07-Nov-23 15:54:19 PTP enabled: True
# 07-Nov-23 15:54:19 PTP enabled: True
# 07-Nov-23 15:54:19 PTP enabled: True
# 07-Nov-23 15:54:19 PTP enabled: True
# 07-Nov-23 15:54:19 PTP enabled: True
# 07-Nov-23 15:54:19 PTP enabled: True
# 07-Nov-23 15:54:19 1
# 07-Nov-23 15:54:19 1
# 07-Nov-23 15:54:19 1
# 07-Nov-23 15:54:19 1
# 07-Nov-23 15:54:19 1
# 07-Nov-23 15:54:19 1
# 07-Nov-23 15:54:19 1
# 07-Nov-23 15:54:19 1
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.1.videoPositionTracking
# /home/sambray/Documents/trodes_to_nwb/src/trodes_to_nwb/convert_position.py:126: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 big frame jumps: [8]
# 07-Nov-23 15:54:19 big frame jumps: [8]
# 07-Nov-23 15:54:19 big frame jumps: [8]
# 07-Nov-23 15:54:19 big frame jumps: [8]
# 07-Nov-23 15:54:19 big frame jumps: [8]
# 07-Nov-23 15:54:19 big frame jumps: [8]
# 07-Nov-23 15:54:19 big frame jumps: [8]
# 07-Nov-23 15:54:19 big frame jumps: [8]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# /home/sambray/Documents/trodes_to_nwb/src/trodes_to_nwb/convert_position.py:126: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 2
# 07-Nov-23 15:54:19 2
# 07-Nov-23 15:54:19 2
# 07-Nov-23 15:54:19 2
# 07-Nov-23 15:54:19 2
# 07-Nov-23 15:54:19 2
# 07-Nov-23 15:54:19 2
# 07-Nov-23 15:54:19 2
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_timestamps_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoTimeStamps.cameraHWSync
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# 07-Nov-23 15:54:19 	position_tracking_filepath: /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.1.videoPositionTracking
# /home/sambray/Documents/trodes_to_nwb/src/trodes_to_nwb/convert_position.py:126: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 repeat timestamps ind: []
# 07-Nov-23 15:54:19 big frame jumps: []
# 07-Nov-23 15:54:19 big frame jumps: []
# 07-Nov-23 15:54:19 big frame jumps: []
# 07-Nov-23 15:54:19 big frame jumps: []
# 07-Nov-23 15:54:19 big frame jumps: []
# 07-Nov-23 15:54:19 big frame jumps: []
# 07-Nov-23 15:54:19 big frame jumps: []
# 07-Nov-23 15:54:19 big frame jumps: []
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# 07-Nov-23 15:54:19 	non_repeat_timestamp_labels = [1]
# /home/sambray/Documents/trodes_to_nwb/src/trodes_to_nwb/convert_position.py:126: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return np.dtype(typearr)
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 Camera frame rate estimated from MCU timestamps: 30.0 frames/s
# 07-Nov-23 15:54:19 WRITING: /stelmo/temp/sample20230622.nwb
# 07-Nov-23 15:54:19 WRITING: /stelmo/temp/sample20230622.nwb
# 07-Nov-23 15:54:19 WRITING: /stelmo/temp/sample20230622.nwb
# 07-Nov-23 15:54:19 WRITING: /stelmo/temp/sample20230622.nwb
# 07-Nov-23 15:54:19 WRITING: /stelmo/temp/sample20230622.nwb
# 07-Nov-23 15:54:19 WRITING: /stelmo/temp/sample20230622.nwb
# 07-Nov-23 15:54:19 WRITING: /stelmo/temp/sample20230622.nwb
# 07-Nov-23 15:54:19 WRITING: /stelmo/temp/sample20230622.nwb
# compute multiplex cache /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_01_a1/20230622_sample_01_a1.rec
# compute multiplex cache /home/sambray/Downloads/trodes_to_nwb_demo/20230622_sample_02_a1/20230622_sample_02_a1.rec
# 07-Nov-23 15:54:26 RUNNING NWB INSPECTOR
# 07-Nov-23 15:54:26 RUNNING NWB INSPECTOR
# 07-Nov-23 15:54:26 RUNNING NWB INSPECTOR
# 07-Nov-23 15:54:26 RUNNING NWB INSPECTOR
# 07-Nov-23 15:54:26 RUNNING NWB INSPECTOR
# 07-Nov-23 15:54:26 RUNNING NWB INSPECTOR
# 07-Nov-23 15:54:26 RUNNING NWB INSPECTOR
# 07-Nov-23 15:54:26 RUNNING NWB INSPECTOR
# 07-Nov-23 15:54:27 NWB Inspector output:
# 07-Nov-23 15:54:27 NWB Inspector output:
# 07-Nov-23 15:54:27 NWB Inspector output:
# 07-Nov-23 15:54:27 NWB Inspector output:
# 07-Nov-23 15:54:27 NWB Inspector output:
# 07-Nov-23 15:54:27 NWB Inspector output:
# 07-Nov-23 15:54:27 NWB Inspector output:
# 07-Nov-23 15:54:27 NWB Inspector output:
# 07-Nov-23 15:54:27 [InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 0',
#     location='/general/devices/probe 0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='HeaderDevice',
#     object_name='header_device',
#     location='/general/devices/header_device',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DataAcqDevice',
#     object_name='dataacq_device0',
#     location='/general/devices/dataacq_device0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='CameraDevice',
#     object_name='camera_device 1',
#     location='/general/devices/camera_device 1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='CameraDevice',
#     object_name='camera_device 0',
#     location='/general/devices/camera_device 0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DynamicTable',
#     object_name='task_1',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DynamicTable',
#     object_name='task_0',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_2',
#     location='/processing/position_frame_index/series_2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_1',
#     location='/processing/position_frame_index/series_1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_2',
#     location='/processing/non_repeat_timestamp_labels/series_2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_1',
#     location='/processing/non_repeat_timestamp_labels/series_1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='ElectricalSeries',
#     object_name='e-series',
#     location='/acquisition/e-series',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="The external file '20230622_sample_02_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.",
#     importance=<Importance.CRITICAL: 2>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_image_series_external_file_valid',
#     object_type='ImageSeries',
#     object_name='20230622_sample_02_a1.1.h264',
#     location='/processing/video_files/video/20230622_sample_02_a1.1.h264',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="The external file '20230622_sample_01_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.",
#     importance=<Importance.CRITICAL: 2>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_image_series_external_file_valid',
#     object_type='ImageSeries',
#     object_name='20230622_sample_01_a1.1.h264',
#     location='/processing/video_files/video/20230622_sample_01_a1.1.h264',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='data is not compressed. Consider enabling compression when writing a dataset.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_small_dataset_compression',
#     object_type='ElectricalSeries',
#     object_name='e-series',
#     location='/acquisition/e-series',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Metadata /general/keywords is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_keywords',
#     object_type='NWBFile',
#     object_name='root',
#     location='/',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named video_files. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='video_files',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named tasks. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='tasks',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named sample_count. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='sample_count',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named position_frame_index. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='position_frame_index',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named non_repeat_timestamp_labels. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='non_repeat_timestamp_labels',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named associated_files. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='associated_files',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named analog. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='analog',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='This table has only a single row; it may be better represented by another data type.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_single_row',
#     object_type='DynamicTable',
#     object_name='task_1',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='This table has only a single row; it may be better represented by another data type.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_single_row',
#     object_type='DynamicTable',
#     object_name='task_0',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# )]
# 07-Nov-23 15:54:27 [InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 0',
#     location='/general/devices/probe 0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='HeaderDevice',
#     object_name='header_device',
#     location='/general/devices/header_device',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DataAcqDevice',
#     object_name='dataacq_device0',
#     location='/general/devices/dataacq_device0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='CameraDevice',
#     object_name='camera_device 1',
#     location='/general/devices/camera_device 1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='CameraDevice',
#     object_name='camera_device 0',
#     location='/general/devices/camera_device 0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DynamicTable',
#     object_name='task_1',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DynamicTable',
#     object_name='task_0',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_2',
#     location='/processing/position_frame_index/series_2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_1',
#     location='/processing/position_frame_index/series_1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_2',
#     location='/processing/non_repeat_timestamp_labels/series_2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_1',
#     location='/processing/non_repeat_timestamp_labels/series_1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='ElectricalSeries',
#     object_name='e-series',
#     location='/acquisition/e-series',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="The external file '20230622_sample_02_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.",
#     importance=<Importance.CRITICAL: 2>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_image_series_external_file_valid',
#     object_type='ImageSeries',
#     object_name='20230622_sample_02_a1.1.h264',
#     location='/processing/video_files/video/20230622_sample_02_a1.1.h264',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="The external file '20230622_sample_01_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.",
#     importance=<Importance.CRITICAL: 2>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_image_series_external_file_valid',
#     object_type='ImageSeries',
#     object_name='20230622_sample_01_a1.1.h264',
#     location='/processing/video_files/video/20230622_sample_01_a1.1.h264',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='data is not compressed. Consider enabling compression when writing a dataset.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_small_dataset_compression',
#     object_type='ElectricalSeries',
#     object_name='e-series',
#     location='/acquisition/e-series',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Metadata /general/keywords is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_keywords',
#     object_type='NWBFile',
#     object_name='root',
#     location='/',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named video_files. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='video_files',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named tasks. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='tasks',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named sample_count. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='sample_count',
#     location=None,
# ...
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='tasks',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named sample_count. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='sample_count',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named position_frame_index. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='position_frame_index',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named non_repeat_timestamp_labels. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='non_repeat_timestamp_labels',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named associated_files. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='associated_files',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named analog. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='analog',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='This table has only a single row; it may be better represented by another data type.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_single_row',
#     object_type='DynamicTable',
#     object_name='task_1',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='This table has only a single row; it may be better represented by another data type.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_single_row',
#     object_type='DynamicTable',
#     object_name='task_0',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# )]
# 07-Nov-23 15:54:27 [InspectorMessage(
#     message='missing data type Device (device)',
#     importance=<Importance.PYNWB_VALIDATION: 3>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='ElectrodeGroup',
#     object_type=None,
#     object_name=None,
#     location='general/extracellular_ephys/0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='Probe',
#     object_name='probe 0',
#     location='/general/devices/probe 0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='HeaderDevice',
#     object_name='header_device',
#     location='/general/devices/header_device',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DataAcqDevice',
#     object_name='dataacq_device0',
#     location='/general/devices/dataacq_device0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='CameraDevice',
#     object_name='camera_device 1',
#     location='/general/devices/camera_device 1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='CameraDevice',
#     object_name='camera_device 0',
#     location='/general/devices/camera_device 0',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DynamicTable',
#     object_name='task_1',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Description is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='DynamicTable',
#     object_name='task_0',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_2',
#     location='/processing/position_frame_index/series_2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_1',
#     location='/processing/position_frame_index/series_1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_2',
#     location='/processing/non_repeat_timestamp_labels/series_2',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='TimeSeries',
#     object_name='series_1',
#     location='/processing/non_repeat_timestamp_labels/series_1',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="Description ('no description') is a placeholder.",
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_description',
#     object_type='ElectricalSeries',
#     object_name='e-series',
#     location='/acquisition/e-series',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="The external file '20230622_sample_02_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.",
#     importance=<Importance.CRITICAL: 2>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_image_series_external_file_valid',
#     object_type='ImageSeries',
#     object_name='20230622_sample_02_a1.1.h264',
#     location='/processing/video_files/video/20230622_sample_02_a1.1.h264',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message="The external file '20230622_sample_01_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.",
#     importance=<Importance.CRITICAL: 2>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_image_series_external_file_valid',
#     object_type='ImageSeries',
#     object_name='20230622_sample_01_a1.1.h264',
#     location='/processing/video_files/video/20230622_sample_01_a1.1.h264',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='data is not compressed. Consider enabling compression when writing a dataset.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_small_dataset_compression',
#     object_type='ElectricalSeries',
#     object_name='e-series',
#     location='/acquisition/e-series',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Metadata /general/keywords is missing.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_keywords',
#     object_type='NWBFile',
#     object_name='root',
#     location='/',
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named video_files. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='video_files',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named tasks. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='tasks',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named sample_count. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='sample_count',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named position_frame_index. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='position_frame_index',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named non_repeat_timestamp_labels. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='non_repeat_timestamp_labels',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named associated_files. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='associated_files',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='Processing module is named analog. It is recommended to use the schema module names: ophys, ecephys, icephys, behavior, misc, ogen, retinotopy',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_processing_module_name',
#     object_type='ProcessingModule',
#     object_name='analog',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='This table has only a single row; it may be better represented by another data type.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_single_row',
#     object_type='DynamicTable',
#     object_name='task_1',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# ), InspectorMessage(
#     message='This table has only a single row; it may be better represented by another data type.',
#     importance=<Importance.BEST_PRACTICE_SUGGESTION: 0>,
#     severity=<Severity.LOW: 1>,
#     check_function_name='check_single_row',
#     object_type='DynamicTable',
#     object_name='task_0',
#     location=None,
#     file_path='/stelmo/temp/sample20230622.nwb'
# )]
# 07-Nov-23 15:54:27 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:54:27 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:54:27 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:54:27 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:54:27 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:54:27 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:54:27 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:54:27 NWB Inspector report saved to /stelmo/temp/sample20230622_nwbinspector_report.txt!
# 07-Nov-23 15:54:27 DONE
# 07-Nov-23 15:54:27 DONE
# 07-Nov-23 15:54:27 DONE
# 07-Nov-23 15:54:27 DONE
# 07-Nov-23 15:54:27 DONE
# 07-Nov-23 15:54:27 DONE
# 07-Nov-23 15:54:27 DONE
# 07-Nov-23 15:54:27 DONE
# NWB Inspector found the following 2 critical errors:
#
#
# **************************************************
# NWBInspector Report Summary
#
# Timestamp: 2023-11-07 15:54:27.032954-08:00
# Platform: Linux-5.4.0-164-generic-x86_64-with-glibc2.31
# NWBInspector version: 0.4.31
#
# Found 2 issues over 1 files:
#        2 - CRITICAL
# **************************************************
#
#
# 0  /stelmo/temp/sample20230622.nwb
# ==================================
#
# 0.0  Importance.CRITICAL: check_image_series_external_file_valid - 'ImageSeries' object at location '/processing/video_files/video/20230622_sample_02_a1.1.h264'
#        Message: The external file '20230622_sample_02_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.
#
# 0.1  Importance.CRITICAL: check_image_series_external_file_valid - 'ImageSeries' object at location '/processing/video_files/video/20230622_sample_01_a1.1.h264'
#        Message: The external file '20230622_sample_01_a1.1.h264' does not exist. Please confirm the relative location to the NWBFile.
#
# NWB Inspector found 0 best practice violations
# NWB Inspector found 23 best practice suggestions
# Please see /stelmo/temp/sample20230622_nwbinspector_report.txt for the full NWB Inspector report

# %% [markdown]
# ### Parallel Conversion
#
# Trodes_to_nwb gives you the option to convert nwb sessions in parallel using dask. To take advantage of this feature, set the `n_workers` parameter to some value >1. In this case, a process will be made to convert each session found in the data directory.
#
#   Be conscious of the RAM required per conversion vs the number of parallel conversions.  In general the RAM scales with the duration of the experiment, but not the number of channels.

# %%
from trodes_to_nwb.convert import create_nwbs

query_expression = "'animal' == 'sample' and 'date' == 20230622"  # restricts conversion to a single session

create_nwbs(
    path=data_path,
    probe_metadata_paths=None,
    output_dir="/stelmo/temp/",  # saving to a temporary directory to not clutter up the database.  Please delete when done.
    query_expression=query_expression,
    n_workers=4,
)
